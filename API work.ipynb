# %%
import requests

url = "https://dev132-cricket-live-scores-v1.p.rapidapi.com/playersbyteam.php"

querystring = {"teamid":"4"}

headers = {
    'x-rapidapi-host': "dev132-cricket-live-scores-v1.p.rapidapi.com",
    'x-rapidapi-key': "9a70e104d7msh4dffb1dbb70197bp148c2ejsn7b5e83ba2cf5"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"message":"You are not subscribed to this API."}

# %%
import requests

# %%
result=requests.get('https://cricapi.com/api/matches/')

# %%
result.status_code
# Out:
# 200

# %%
result.text
# Out:
# '{"error":"You need to use the API key you get from www.cricapi.com. Please email us on contact@cricapi.com if you have any doubt.","apikey":null}'

# %%
from pycricbuzz import Cricbuzz
import json
c = Cricbuzz()
matches = c.matches()
print (json.dumps(matches,indent=4)) #for pretty prinitng
# Out:
# [
#     {
#         "id": "27403",
#         "srs": "Pakistan Super League 2020",
#         "mnum": "30th Match",
#         "type": "T20",
#         "mchstate": "mom",
#         "status": "QTG won by 5 wkts",
#         "venue_name": "National Stadium",
#         "venue_location": "Karachi, Pakistan",
#         "toss": "Karachi Kings elect to bat",
#         "official": {
#             "umpire1": {
#                 "id": "11263",
#                 "name": "Rashid Riaz",
#                 "country": "Pak"
#             },
#             "umpire2": {
#                 "id": "8034",
#                 "name": "Michael Gough",
#                 "country": "Eng"
#             },
#             "umpire3": {
#                 "id": "6868",
#                 "name": "Ahsan Raza",
#                 "country": "Pak"
#             },
#             "referee": {
#                 "id": "3538",
#                 "name": "Roshan Mahanama",
#                 "country": "SL"
#             }
# ...

# %%
def live_score(mid):
    c = Cricbuzz()
    lscore = c.livescore(mid)
    print(json.dumps(lscore, indent=4, sort_keys=True))
live_score("27403")
# Out:
# {
#     "batting": {
#         "batsman": [
#             {
#                 "balls": "12",
#                 "fours": "2",
#                 "name": "Azam Khan",
#                 "runs": "12",
#                 "six": "0"
#             },
#             {
#                 "balls": "4",
#                 "fours": "0",
#                 "name": "Mohammad Nawaz",
#                 "runs": "8",
#                 "six": "1"
#             }
#         ],
#         "score": [
#             {
#                 "declare": null,
#                 "inning_num": "2",
#                 "overs": "16.2",
#                 "runs": "154",
#                 "wickets": "5"
#             }
#         ],
#         "team": "Quetta Gladiators"
#     },
#     "bowling": {
#         "bowler": [
#             {
#                 "maidens": "0",
#                 "name": "W Maqsood",
#                 "overs": "4",
#                 "runs": "19",
#                 "wickets": "2"
#             }
#         ],
# ...
